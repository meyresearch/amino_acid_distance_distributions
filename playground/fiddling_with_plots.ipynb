# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DON'T NORMALISE BINS

# %% [markdown]
# # 100

# %%
histogram_100 = np.load("../data/rcsb/histogram_100_not_normed.npy", allow_pickle=True)
alpha_100 = np.load("../data/alphafold/histogram_100_not_normed.npy", allow_pickle=True)
simulation_100 = np.load("../data/simulations/3d/histogram_100_not_normed.npy", allow_pickle=True)
distances = np.linspace(1, 350, 350)[:-1]

# %%
mean_100 = np.mean(histogram_100, axis=0)
normed_mean_100 = mean_100 / np.sum(mean_100)

alpha_mean_100 = np.mean(alpha_100, axis=0)
normed_alpha_mean_100 = alpha_mean_100 / np.sum(alpha_mean_100)

alpha_median_100 = np.median(alpha_100, axis=0)
normed_alpha_median_100 = alpha_median_100 / np.sum(alpha_median_100)

median_100 = np.median(histogram_100, axis=0)
normed_median_100 = median_100 / np.sum(median_100)

sim_mean_100 = np.mean(simulation_100, axis=0)
normed_sim_mean_100 = sim_mean_100 / np.sum(sim_mean_100)

sim_median_100 = np.median(simulation_100, axis=0)
normed_sim_median_100 = sim_median_100 / np.sum(sim_median_100)

# %%
plt.scatter(distances, normed_mean_100, label="Mean 100")
# plt.scatter(distances, normed_alpha_mean_100, label="Alpha mean 100")
# plt.scatter(distances, normed_sim_mean_100, label="Sim mean 100")
plt.loglog()
plt.legend()
plt.ylim(0.0001,0.9)
plt.xlim(1,100)
# Out:
# (1, 100)

# %%
plt.scatter(distances, normed_median_100, label="Median 100")
plt.scatter(distances, normed_alpha_median_100, label="Alpha median 100")
plt.scatter(distances, normed_sim_median_100, label="Sim median 100")
plt.loglog()
plt.ylim(0.001, 0.1)
plt.xlim(3, 100)
plt.legend()

# %%
alpha_100 = np.load("../data/alphafold/histogram_100_not_normed.npy", allow_pickle=True)
alpha_200 = np.load("../data/alphafold/histogram_200_not_normed.npy", allow_pickle=True)
alpha_300 = np.load("../data/alphafold/histogram_300_not_normed.npy", allow_pickle=True)
distances = np.linspace(1, 300, 300)[:-1]

# %%
alpha_mean_100 = np.mean(alpha_100, axis=0)
normed_alpha_mean_100 = alpha_mean_100 / np.sum(alpha_mean_100)

alpha_median_100 = np.median(alpha_100, axis=0)
normed_alpha_median_100 = alpha_median_100 / np.sum(alpha_median_100)

alpha_mean_200 = np.mean(alpha_200, axis=0)
normed_alpha_mean_200 = alpha_mean_200 / np.sum(alpha_mean_200)

alpha_median_200 = np.median(alpha_200, axis=0)
normed_alpha_median_200 = alpha_median_200 / np.sum(alpha_median_200)

alpha_mean_300 = np.mean(alpha_300, axis=0)
normed_alpha_mean_300 = alpha_mean_300 / np.sum(alpha_mean_300)

alpha_median_300 = np.median(alpha_300, axis=0)
normed_alpha_median_300 = alpha_median_300 / np.sum(alpha_median_300)

# %%
plt.scatter(distances, normed_alpha_mean_100, label="Mean 100")
plt.scatter(distances, normed_alpha_mean_200, label="Mean 200")
plt.scatter(distances, normed_alpha_mean_300, label="Mean 300")
plt.ylim(0.0001, 0.1)
plt.xlim(3, 300)
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_alpha_median_100, label="Median 100")
plt.scatter(distances, normed_alpha_median_200, label="Median 200")
plt.scatter(distances, normed_alpha_median_300, label="Mean 300")
plt.loglog()
plt.ylim(0.0001, 0.1)
plt.xlim(3, 300)
plt.legend()

# %% [markdown]
# # 200

# %%
histogram_200 = np.load("../data/rcsb/histogram_200_not_normed.npy", allow_pickle=True)
alpha_200 = np.load("../data/alphafold/histogram_200_not_normed.npy", allow_pickle=True)
simulation_200 = np.load("../data/simulations/3d/histogram_200_not_normed.npy", allow_pickle=True)
distances = np.linspace(1, 350, 350)[:-1]

# %%
mean_200 = np.mean(histogram_200, axis=0)
normed_mean_200 = mean_200 / np.sum(mean_200)

alpha_mean_200 = np.mean(alpha_200, axis=0)
normed_alpha_mean_200 = alpha_mean_200 / np.sum(alpha_mean_200)

alpha_median_200 = np.median(alpha_200, axis=0)
normed_alpha_median_200 = alpha_median_200 / np.sum(alpha_median_200)

median_200 = np.median(histogram_200, axis=0)
normed_median_200 = median_200 / np.sum(median_200)

sim_mean_200 = np.mean(simulation_200, axis=0)
normed_sim_mean_200 = sim_mean_200 / np.sum(sim_mean_200)

sim_median_200 = np.median(simulation_200, axis=0)
normed_sim_median_200 = sim_median_200 / np.sum(sim_median_200)

# %%
plt.scatter(distances, normed_mean_200, label="Mean 200")
# plt.scatter(distances, normed_alpha_mean_200, label="Alpha mean 200")
# plt.scatter(distances, normed_sim_mean_200, label="Sim mean 200")
plt.loglog()
plt.legend()
plt.ylim(0.0001,0.9)
plt.xlim(1,150)
# Out:
# (1, 150)

# %%
plt.scatter(distances, normed_median_200, label="Median 200")
plt.scatter(distances, normed_alpha_median_200, label="Alpha median 200")
plt.scatter(distances, normed_sim_median_200, label="Sim median 200")
plt.loglog()

plt.legend()

# %% [markdown]
# # 300

# %%
histogram_300 = np.load("../data/rcsb/histogram_300_not_normed.npy", allow_pickle=True)
alpha_300 = np.load("../data/alphafold/histogram_300_not_normed.npy", allow_pickle=True)
simulation_300 = np.load("../data/simulations/3d/histogram_300_not_normed.npy", allow_pickle=True)
distances = np.linspace(1, 350, 350)[:-1]

# %%
histogram_300.shape
# Out:
# (10091, 349)

# %%
for i in range(histogram_300.shape[1]):
    plt.plot(distances, histogram_300[:][i], label="Mean 300")
    # plt.scatter(distances, normed_alpha_mean_300, label="Alpha mean 300")
    # plt.scatter(distances, normed_sim_mean_300, label="Sim mean 300")
    #plt.loglog()
# plt.legend()
# plt.ylim(0.00001,0.9)
# plt.yscale("log")
plt.xlim(0,20)
# Out:
# (0.0, 20.0)

# %%
for i in range(histogram_300.shape[1]):
    plt.plot(distances, histogram_300[:][i], label="Mean 300")
    # plt.scatter(distances, normed_alpha_mean_300, label="Alpha mean 300")
    # plt.scatter(distances, normed_sim_mean_300, label="Sim mean 300")
    #plt.loglog()
# plt.legend()
# plt.ylim(0.00001,0.9)
plt.xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
mean_300 = np.mean(histogram_300, axis=0)
normed_mean_300 = mean_300 / np.sum(mean_300)

alpha_mean_300 = np.mean(alpha_300, axis=0)
normed_alpha_mean_300 = alpha_mean_300 / np.sum(alpha_mean_300)

alpha_median_300 = np.median(alpha_300, axis=0)
normed_alpha_median_300 = alpha_median_300 / np.sum(alpha_median_300)

median_300 = np.median(histogram_300, axis=0)
normed_median_300 = median_300 / np.sum(median_300)

sim_mean_300 = np.mean(simulation_300, axis=0)
normed_sim_mean_300 = sim_mean_300 / np.sum(sim_mean_300)

sim_median_300 = np.median(simulation_300, axis=0)
normed_sim_median_300 = sim_median_300 / np.sum(sim_median_300)

# %%
plt.scatter(distances, normed_mean_300, label="Mean 300")
# plt.scatter(distances, normed_alpha_mean_300, label="Alpha mean 300")
# plt.scatter(distances, normed_sim_mean_300, label="Sim mean 300")
plt.loglog()
plt.legend()
plt.ylim(0.00001,0.9)
# Out:
# (1e-05, 0.9)

# %%
plt.scatter(distances, normed_median_300, label="Median 300")
plt.scatter(distances, normed_alpha_median_300, label="Alpha median 300")
plt.scatter(distances, normed_sim_median_300, label="Sim median 300")
plt.loglog()

plt.legend()

# %% [markdown]
# # NOW NORMALISE BINS

# %% [markdown]
# # 100

# %%
histogram_100 = np.load("../data/rcsb/histogram_100_not_normed.npy", allow_pickle=True)
alpha_100 = np.load("../data/alphafold/histogram_100_not_normed.npy", allow_pickle=True)
simulation_100 = np.load("../data/simulations/3d/histogram_100_not_normed.npy", allow_pickle=True)
distances = np.linspace(1, 300, 300)[:-1]

# %%
normed_100 = []
for counts in histogram_100:
    counts = counts / counts.sum()
    normed_100.append(counts)
normed_100 = np.asarray(normed_100)

# %%
normed_alpha_100 = []
for counts in alpha_100:
    counts = counts / counts.sum()
    normed_alpha_100.append(counts)
normed_alpha_100 = np.asarray(normed_alpha_100)

# %%
normed_sim_100 = []
for counts in simulation_100:
    counts = counts / counts.sum()
    normed_sim_100.append(counts)
normed_sim_100 = np.asarray(normed_sim_100)

# %%
jmean_100 = np.mean(normed_100, axis=0)
normed_jmean_100 = jmean_100 / np.sum(jmean_100)

# %%
jmedian_100 = np.median(normed_100, axis=0)
normed_jmedian_100 = jmedian_100 / np.sum(jmedian_100)

# %%
alpha_jmean_100 = np.mean(normed_alpha_100, axis=0)
normed_alpha_jmean_100 = alpha_jmean_100 / np.sum(alpha_jmean_100)

# %%
alpha_jmedian_100 = np.median(normed_alpha_100, axis=0)
normed_alpha_jmedian_100 = alpha_jmedian_100 / np.sum(alpha_jmedian_100)

# %%
sim_jmean_100 = np.mean(normed_sim_100, axis=0)
normed_sim_jmean_100 = sim_jmean_100 / np.sum(sim_jmean_100)

# %%
sim_jmedian_100 = np.median(normed_sim_100, axis=0)
normed_sim_jmedian_100 = sim_jmedian_100 / np.sum(sim_jmedian_100)

# %%
plt.scatter(distances, normed_jmean_100, label="j Mean 100")
plt.scatter(distances, normed_alpha_jmean_100, label="Alpha j mean 100")
plt.scatter(distances, normed_sim_jmean_100, label="Sim j mean 100")
plt.xlim(5,50)
plt.ylim(0.0001,0.1)
plt.loglog()
plt.legend()

# %% [markdown]
# # DO THIS !!!!!

# %%
normed_mean_100 = normed_mean_100 / normed_mean_100[4]
normed_sim_mean_100 = normed_sim_mean_100 / normed_sim_mean_100[4]
plt.scatter(distances, normed_mean_100, label="Mean 100")
plt.scatter(distances, normed_sim_mean_100, label="Sim mean 100")
plt.xlim(5,50)
plt.ylim(0.001,10)
plt.loglog()
# Out:
# []

# %%
plt.scatter(distances, normed_jmedian_100, label="j median 100")
plt.scatter(distances, normed_alpha_jmedian_100, label="Alpha j median 100")
plt.scatter(distances, normed_sim_jmedian_100, label="Sim j median 100")
plt.loglog()
plt.legend()

# %% [markdown]
# # 200

# %%
histogram_200 = np.load("../data/rcsb/histogram_200_not_normed.npy", allow_pickle=True)
alpha_200 = np.load("../data/alphafold/histogram_200_not_normed.npy", allow_pickle=True)
simulation_200 = np.load("../data/simulations/3d/histogram_200_not_normed.npy", allow_pickle=True)
distances = np.linspace(1, 300, 300)[:-1]

# %%
normed_200 = []
for counts in histogram_200:
    counts = counts / counts.sum()
    normed_200.append(counts)
normed_200 = np.asarray(normed_200)

# %%
normed_alpha_200 = []
for counts in alpha_200:
    counts = counts / counts.sum()
    normed_alpha_200.append(counts)
normed_alpha_200 = np.asarray(normed_alpha_200)

# %%
normed_sim_200 = []
for counts in simulation_200:
    counts = counts / counts.sum()
    normed_sim_200.append(counts)
normed_sim_200 = np.asarray(normed_sim_200)

# %%
jmean_200 = np.mean(normed_200, axis=0)
normed_jmean_200 = jmean_200 / np.sum(jmean_200)

jmedian_200 = np.median(normed_200, axis=0)
normed_jmedian_200 = jmedian_200 / np.sum(jmedian_200)

alpha_jmean_200 = np.mean(normed_alpha_200, axis=0)
normed_alpha_jmean_200 = alpha_jmean_200 / np.sum(alpha_jmean_200)

alpha_jmedian_200 = np.median(normed_alpha_200, axis=0)
normed_alpha_jmedian_200 = alpha_jmedian_200 / np.sum(alpha_jmedian_200)

sim_jmean_200 = np.mean(normed_sim_200, axis=0)
normed_sim_jmean_200 = sim_jmean_200 / np.sum(sim_jmean_200)

sim_jmedian_200 = np.median(normed_sim_200, axis=0)
normed_sim_jmedian_200 = sim_jmedian_200 / np.sum(sim_jmedian_200)

# %%
plt.scatter(distances, normed_jmean_200, label="j Mean 200")
plt.scatter(distances, normed_alpha_jmean_200, label="Alpha j mean 200")
plt.scatter(distances, normed_sim_jmean_200, label="Sim j mean 200")
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_jmedian_200, label="j median 200")
plt.scatter(distances, normed_alpha_jmedian_200, label="Alpha j median 200")
plt.scatter(distances, normed_sim_jmedian_200, label="Sim j median 200")
plt.loglog()
plt.legend()

# %% [markdown]
# # 300

# %%
histogram_300 = np.load("../data/rcsb/histogram_300_not_normed.npy", allow_pickle=True)
alpha_300 = np.load("../data/alphafold/histogram_300_not_normed.npy", allow_pickle=True)
simulation_300 = np.load("../data/simulations/3d/histogram_300_not_normed.npy", allow_pickle=True)
distances = np.linspace(1, 300, 300)[:-1]

# %%
normed_300 = []
for counts in histogram_300:
    counts = counts / counts.sum()
    normed_300.append(counts)
normed_300 = np.asarray(normed_300)

normed_alpha_300 = []
for counts in alpha_300:
    counts = counts / counts.sum()
    normed_alpha_300.append(counts)
normed_alpha_300 = np.asarray(normed_alpha_300)

normed_sim_300 = []
for counts in simulation_300:
    counts = counts / counts.sum()
    normed_sim_300.append(counts)
normed_sim_300 = np.asarray(normed_sim_300)

# %%
# Out:
# 10090.999999999996

# %%
jmean_300 = np.mean(normed_300, axis=0)
normed_jmean_300 = jmean_300 / np.sum(jmean_300)

jmedian_300 = np.median(normed_300, axis=0)
normed_jmedian_300 = jmedian_300 / np.sum(jmedian_300)

alpha_jmean_300 = np.mean(normed_alpha_300, axis=0)
normed_alpha_jmean_300 = alpha_jmean_300 / np.sum(alpha_jmean_300)

alpha_jmedian_300 = np.median(normed_alpha_300, axis=0)
normed_alpha_jmedian_300 = alpha_jmedian_300 / np.sum(alpha_jmedian_300)

sim_jmean_300 = np.mean(normed_sim_300, axis=0)
normed_sim_jmean_300 = sim_jmean_300 / np.sum(sim_jmean_300)

sim_jmedian_300 = np.median(normed_sim_300, axis=0)
normed_sim_jmedian_300 = sim_jmedian_300 / np.sum(sim_jmedian_300)

# %%
plt.scatter(distances, normed_jmean_300, label="j Mean 300")
plt.scatter(distances, normed_alpha_jmean_300, label="Alpha j mean 300")
plt.scatter(distances, normed_sim_jmean_300, label="Sim j mean 300")
plt.xlim(5,150)
plt.ylim(0.001,10)
plt.loglog()
# Out:
# []

# %%
normed_mean_300 = normed_mean_300 / normed_mean_300[4]
normed_sim_mean_300 = normed_sim_mean_300 / normed_sim_mean_300[4]
plt.scatter(distances, normed_mean_300, label="Mean 300")
plt.scatter(distances, normed_sim_mean_300, label="Sim mean 300")
plt.xlim(5,150)
plt.ylim(0.001,10)
plt.loglog()
# Out:
# []

# %%
plt.scatter(distances, normed_jmedian_300, label="j median 300")
plt.scatter(distances, normed_alpha_jmedian_300, label="Alpha j median 300")
plt.scatter(distances, normed_sim_jmedian_300, label="Sim j median 300")
plt.loglog()
plt.legend()

# %% [markdown]
# # COMPARISON

# %%
histogram_100 = np.load("../data/rcsb/histogram_100.npy", allow_pickle=True)
alpha_100 = np.load("../data/alphafold/histogram_100.npy", allow_pickle=True)
simulation_100 = np.load("../data/simulations/3d/histogram_100.npy", allow_pickle=True)

mean_100 = np.mean(histogram_100, axis=0)
normed_mean_100_old = mean_100 / np.sum(mean_100)
old_distances = np.linspace(start=1, stop=100, num=100)[:-1]

plt.scatter(old_distances, normed_mean_100_old, label="Density=True", zorder=10)
plt.scatter(distances, normed_mean_100, label="Mean 100")
plt.scatter(distances, normed_jmean_100, label="j Mean 100")
plt.scatter(distances, normed_median_100, label="Mean 100")
plt.xlim(1,50)
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_alpha_mean_100, label="Alpha mean 100")
plt.scatter(distances, normed_alpha_jmean_100, label="Alpha j mean 100")
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_sim_mean_100, label="Sim mean 100")
plt.scatter(distances, normed_sim_jmean_100, label="Sim j mean 100")
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_mean_200, label="Mean 200")
plt.scatter(distances, normed_jmean_200, label="j Mean 200")
plt.xlim(1,100)
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_alpha_mean_200, label="Alpha mean 200")
plt.scatter(distances, normed_alpha_jmean_200, label="Alpha j mean 200")

plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_mean_300, label="Mean 300")
plt.scatter(distances, normed_jmean_300, label="j Mean 300")
plt.xlim(1,150)
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_alpha_mean_300, label="Alpha mean 300")
plt.scatter(distances, normed_alpha_jmean_300, label="Alpha j mean 300")
plt.scatter(distances, normed_alpha_jmedian_300, label="Alpha j median 300")
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_sim_mean_300, label="Sim mean 300")
plt.scatter(distances, normed_sim_jmean_300, label="Sim j mean 300")
plt.loglog()
plt.legend()

# %%
plt.scatter(distances, normed_alpha_median_300, label="Alpha median 300")
plt.scatter(distances, normed_alpha_jmedian_300, label="Alpha j median 300")
plt.loglog()
# Out:
# []
