# %% [markdown]
# # Percentage plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

_PATHS = {"ALPHA":"/home/jguven/Projects/sequence_distance_distribution/data/alphafold/",
          "RCSB":"/home/jguven/Projects/sequence_distance_distribution/data/rcsb/"}

# %%
def plot_percentages(dataframe: pd.DataFrame) -> None:
    """
    Take secondary structure information and plot alpha percentage vs beta percentage
    @param dataframe: secondary structure info in each length range
    @return: None
    """
    fig = plt.figure(figsize=(8,8))
    ax = fig.subplots(1,1)
    ax.scatter(df["H"], df["beta"], c=df["mean"], cmap="coolwarm_r")
    ax.set_xlabel(r"$\alpha$-helix %")
    ax.set_ylabel(r"$\beta$-sheet %")

# %% [markdown]
# ## AlphaFold 2

# %% [markdown]
# ### Chain lengths in the range 85-100

# %%
df = pd.read_csv(_PATHS["ALPHA"]+"secondary_structures_100.csv").dropna()
df
# Out:
#        Unnamed: 0                                           filename  \
# 3               3  /home/jguven/Projects/sequence_distance_distri...
# 4               4  /home/jguven/Projects/sequence_distance_distri...
# 16             16  /home/jguven/Projects/sequence_distance_distri...
# 21             21  /home/jguven/Projects/sequence_distance_distri...
# 25             25  /home/jguven/Projects/sequence_distance_distri...
# ...           ...                                                ...
# 17336       17336  /home/jguven/Projects/sequence_distance_distri...
# 17344       17344  /home/jguven/Projects/sequence_distance_distri...
# 17354       17354  /home/jguven/Projects/sequence_distance_distri...
# 17357       17357  /home/jguven/Projects/sequence_distance_distri...
# 17366       17366  /home/jguven/Projects/sequence_distance_distri...
#
#             mean        std         H      beta
# 3      96.222855   5.478534  0.336364  0.109091
# ...

# %%
plot_percentages(df)
plt.show()

# %% [markdown]
# ### Chain lengths in the range 185-215

# %%
df = pd.read_csv(_PATHS["ALPHA"]+"secondary_structures_200.csv").dropna()
df
# Out:
#        Unnamed: 0                                           filename  \
# 3               3  /home/jguven/Projects/sequence_distance_distri...
# 4               4  /home/jguven/Projects/sequence_distance_distri...
# 16             16  /home/jguven/Projects/sequence_distance_distri...
# 21             21  /home/jguven/Projects/sequence_distance_distri...
# 25             25  /home/jguven/Projects/sequence_distance_distri...
# ...           ...                                                ...
# 24653       24653  /home/jguven/Projects/sequence_distance_distri...
# 24656       24656  /home/jguven/Projects/sequence_distance_distri...
# 24659       24659  /home/jguven/Projects/sequence_distance_distri...
# 24661       24661  /home/jguven/Projects/sequence_distance_distri...
# 24663       24663  /home/jguven/Projects/sequence_distance_distri...
#
#             mean        std         H      beta
# 3      94.343163   6.660580  0.336364  0.109091
# ...

# %%
plot_percentages(df)
plt.show()

# %% [markdown]
# ### Chain lengths in the range 285-315

# %%
df = pd.read_csv(_PATHS["ALPHA"]+"secondary_structures_300.csv").dropna()
df
# Out:
#        Unnamed: 0                                           filename  \
# 3               3  /home/jguven/Projects/sequence_distance_distri...
# 4               4  /home/jguven/Projects/sequence_distance_distri...
# 16             16  /home/jguven/Projects/sequence_distance_distri...
# 21             21  /home/jguven/Projects/sequence_distance_distri...
# 25             25  /home/jguven/Projects/sequence_distance_distri...
# ...           ...                                                ...
# 21799       21799  /home/jguven/Projects/sequence_distance_distri...
# 21800       21800  /home/jguven/Projects/sequence_distance_distri...
# 21801       21801  /home/jguven/Projects/sequence_distance_distri...
# 21804       21804  /home/jguven/Projects/sequence_distance_distri...
# 21805       21805  /home/jguven/Projects/sequence_distance_distri...
#
#             mean        std         H      beta
# 3      96.871468   3.243266  0.336364  0.109091
# ...

# %%
plot_percentages(df)
plt.show()

# %% [markdown]
# ## RCSB PDB
